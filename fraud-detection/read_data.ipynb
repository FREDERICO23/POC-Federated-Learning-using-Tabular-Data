# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read data

# %%
data = pd.read_csv("creditcard.csv")
data.sample(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 212915  139039.0 -4.040413  2.622909 -2.443762 -0.967314 -1.199774 -1.472900
# 62476    50282.0 -0.830893  0.702480  1.832422 -0.426275 -1.243311 -0.250197
# 185753  126810.0  0.308615 -0.469102 -1.550750 -2.051320  1.370651 -0.837395
# 35215    38018.0  1.191142 -0.335213 -0.344326 -0.881741 -0.365378 -0.892940
# 77449    57055.0 -0.355680  0.909893  1.180642 -0.213030  0.193505 -0.454046
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 212915 -0.376405  1.827454  0.432744  ... -0.145790 -0.286458  0.044423
# 62476  -0.138399  0.438705  0.278531  ...  0.023231  0.089003 -0.018313
# 185753  1.780701 -1.095026 -1.192660  ...  0.394021  1.537766  0.024027
# 35215   0.175858 -0.141745  1.065129  ...  0.033961  0.164916 -0.284323
# 77449   0.584199  0.076039 -0.100581  ... -0.300767 -0.877621 -0.105111
#
# ...

# %% [markdown]
# ### Exploratory data Analysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
data['Time'].value_counts()
# Out:
# 163152.0    36
# 64947.0     26
# 68780.0     25
# 3767.0      21
# 3770.0      20
#             ..
# 127750.0     1
# 62260.0      1
# 62259.0      1
# 127753.0     1
# 172792.0     1
# Name: Time, Length: 124592, dtype: int64

# %%
# distribution of legit transaction and fraudlent transaction
data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
# Compare the values for both transactions
data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Frauds transactions are more than the legit transactions

# %% [markdown]
# ### Data Preprocessing

# %%
df = data.copy()

# %%
# separating the data for analysis and data sample creation
legit = df[df.Class == 0]
fraud = df[df.Class == 1]

# %%
print("Fraud Transactions: ",fraud.shape)
print("Legit Transactions: ", legit.shape)
# Out:
# Fraud Transactions:  (492, 31)
# Legit Transactions:  (284315, 31)

# %%
## Take a sample of atleast 90% more of the Fraud transaction to reduce biasness in the data
legit_sample = legit.sample(n=4920)

## Do for another datasets for federated learning
legit_sample1 = legit.sample(n=4000)

# %%
# Concatenante the legit sample and the fraud to create a less biased dataset
import random

dfs = [legit_sample, fraud]
random.shuffle(dfs)
new_df = pd.concat(dfs, axis=0)

## Do for another datasets for federated learning
dfs = [legit_sample1, fraud]
random.shuffle(dfs)
df1 = pd.concat(dfs, axis=0)


new_df.shape
# Out:
# (5412, 31)

# %%
df1
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 57511    47940.0 -2.454371 -0.530124  0.536537 -0.880329 -1.478787  1.034731
# 276546  167158.0  2.077585 -0.171763 -1.484913  0.069503  0.377610 -0.310130
# 135389   81230.0  1.092632 -0.501921  0.978936  0.023468 -0.756248  0.625159
# 108452   70907.0  0.030371  1.603173 -2.217304  1.610322  1.253953 -0.125151
# 170723  120325.0  1.995590  0.480158 -2.284514  1.384684  0.989221 -0.756335
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
new_df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      95403.432724  0.064396 -0.015935  0.005381 -0.029717 -0.008624
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.007480 -0.005705 -0.021437  0.027551  ... -0.028142 -0.005187
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.009653  0.002804  0.013108 -0.000163 -0.004985 -0.000048  0.008090
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       83.774833
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
X = new_df.drop(columns = 'Class',axis = 1)
y = new_df['Class']

# %% [markdown]
# ### Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2, stratify = y, random_state = 23)
print(X_train.shape, X_test.shape, y_train.shape,y_test.shape)
# Out:
# (4329, 30) (1083, 30) (4329,) (1083,)

# %%
lr =  LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
preds = lr.predict(X_test)

# %%
pred = accuracy_score(preds, y_test)
pred
# Out:
# 0.9806094182825484

# %%
# Create new data out of the samples
new_df.to_csv("data1.csv")
df1.to_csv("credit.csv")

# %%
df2 = []
# Out:
# (284807, 31)

# %% [markdown]
# ### Using SMOTE to solve data imbalance

# %%
from typing import Counter
from imblearn.over_sampling import SMOTE

counter =  Counter(y)
print('Before:', counter)

# oversampling the dataset using SMOTE
smt = SMOTE()
x_sm, y_sm = smt.fit_resample(X, y)

counter = Counter(y_sm)
print('After:', counter)
# Out:
# Before: Counter({0: 4920, 1: 492})
# After: Counter({1: 4920, 0: 4920})

# %%
print(y_sm.shape, y.shape)
# Out:
# (9840,) (5412,)

# %%
print(x_sm.shape, X.shape)
# Out:
# (9840, 30) (5412, 30)

# %%
X_train1,X_test1,y_train1,y_test1 = train_test_split(x_sm,y_sm,test_size = 0.2, stratify = y_sm, random_state = 23)
print(X_train.shape, X_test.shape, y_train.shape,y_test.shape)
# Out:
# (4329, 30) (1083, 30) (4329,) (1083,)

# %%
model =  LogisticRegression()
model.fit(X_train1,y_train1)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
preds = lr.predict(X_test1)

# %%
pred = accuracy_score(preds, y_test1)
pred
# Out:
# 0.959349593495935

# %%
x_sm
# Out:
#                Time         V1        V2         V3        V4        V5  \
# 0        406.000000  -2.312227  1.951992  -1.609851  3.997906 -0.522188
# 1        472.000000  -3.043541 -3.157307   1.088463  2.288644  1.359805
# 2       4462.000000  -2.303350  1.759247  -0.359745  2.330243 -0.821628
# 3       6986.000000  -4.397974  1.358367  -2.592844  2.679787 -1.128131
# 4       7519.000000   1.234235  3.019740  -4.304597  4.732795  3.624201
# ...             ...        ...       ...        ...       ...       ...
# 9835  132999.155503  -1.069376 -1.875696  -5.820460  3.004982 -0.655496
# 9836   25282.360458 -11.930394  8.062857 -14.852556  5.137159 -9.334276
# 9837   93853.000000  -5.839192  7.151532 -12.816760  7.031115 -9.651272
# 9838   43200.724461  -3.832687  2.082684  -5.157686  2.315898 -3.530289
# 9839   77185.544803  -1.223948  2.120636  -2.034531  1.892916  0.569216
#
#             V6         V7        V8        V9  ...       V20       V21  \
# ...
